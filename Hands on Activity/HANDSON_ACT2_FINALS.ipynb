# %% [markdown]
# ## **MILITARY RANK & SALARY TABLE**
# This section contains rank–salary pairs stored in a Python dictionary.

# %%
soldier_rank = {
    "Recruit":"$500",
    "Private":"$600",
    "Private First Class":"$650",
    "Lance Corporal":"$700",
    "Corporal":"$750",
    "Sergeant":"$800",
    "Staff Sergeant":"$850",
    "Sergeant First Class":"$900",
    "Master Sergeant":"$950",
    "First Sergeant":"$1000",
    "Sergeant Major":"$1050",
    "Command Sergeant Major":"$1100",
    "Warrant Officer 1":"$1150",
    "Warrant Officer 2":"$1200",
    "Warrant Officer 3":"$1250",
    "Warrant Officer 4":"$1300",
    "Warrant Officer 5":"$1350",
    "Second Lieutenant":"$1400",
    "First Lieutenant":"$1450",
    "Captain":"$1500",
    "Major":"$1600",
    "Lieutenant Colonel":"$1700",
    "Colonel":"$1800",
    "Brigadier General":"$2000",
    "Major General":"$2200"
}

soldier_rank["Captain"]="$1570"
soldier_rank["Colonet"]="$1950"
soldier_rank["Major General"]="$2500"

print(soldier_rank["Sergeant Major"])

teacher_rank = {
    "Assistant Teacher": "$2000",
    "Junior Teacher": "$2200",
    "Senior Teacher": "$2500",
    "Subject Teacher": "$2700",
    "Homeroom Teacher": "$2900",
    "Special Education Teacher": "$3000",
    "ESL Teacher": "$3100",
    "Computer Teacher": "$3200",
    "Science Teacher": "$3300",
    "Math Teacher": "$3400",
    "Social Studies Teacher": "$3300",
    "Language Teacher": "$3200",
    "Arts Teacher": "$2800",
    "Physical Education Teacher": "$2900",
    "Librarian / Media Specialist": "$3000",
    "Senior Subject Coordinator": "$3500",
    "Curriculum Developer": "$4000",
    "Academic Coordinator": "$4200",
    "Vice Principal (Academics)": "$4800",
    "Vice Principal (Administration)": "$5000",
    "Head of Department (HOD)": "$4500",
    "Principal": "$6500",
    "School Director": "$7500",
    "Academic Dean": "$8000",
    "Education Consultant": "$8500"
}

teacher_rank["Computer Teacher"]="$3300"
teacher_rank["Principal"]="$7000"
teacher_rank["Academic Dean"]="$8300"

print(teacher_rank["Principal"])
# Out:
# $1050
# $7000
