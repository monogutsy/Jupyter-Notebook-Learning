# %% [markdown]
# ## **🍎 FRUIT AND VEGETABLE ITEMS**
#  A collection of fresh nutritious fruits and vegetables.

# %%
list1=[
    "Apple","Banana","Orange","Mango","Pineapple","Stawberry","Rasberry","Grape","Watermelon","Papaya","Kiwi","Peach","Plum","Pear","Chear","Lemon","Lime","Coconot","Apricot","Fig","Guava","Lychee","Dragon Fruit","Tangerine","Passion Fruit"
    ]
list2=[
    "Carrot","Broccoli","Spinach","Potato","Tomato","Cucumber","Lettuce","Kale","Cauliflower","Bell Pepper","Onion","Garlic","Eggplant","Zucchini","Cabbage","Peas","Sweet Corn","Calery","Asparagus","Brussels Sprouts","Radish","Beetroot","Pumpkin","Green Beens","Okra"
]
list1.append("Avocado")
list1.append("Ponkan")
list1.append("Turnip")
list1.remove("Apple")
list1.remove("Papaya")
list1.remove("Peach")
list1.pop()
list1.pop()
print(list1[12:18])

list2.append("Yam")
list2.append("Mushroom")
list2.append("Spring Onion")
list2.remove("Broccoli")
list2.remove("Sweet Corn")
list2.remove("Calery")
list2.pop()
list2.pop()
print(list2[:9])

list1,list2
# Out:
# ['Lemon', 'Lime', 'Coconot', 'Apricot', 'Fig', 'Guava']
# ['Carrot', 'Spinach', 'Potato', 'Tomato', 'Cucumber', 'Lettuce', 'Kale', 'Cauliflower', 'Bell Pepper']
# (['Banana',
#   'Orange',
#   'Mango',
#   'Pineapple',
#   'Stawberry',
#   'Rasberry',
#   'Grape',
#   'Watermelon',
#   'Kiwi',
#   'Plum',
#   'Pear',
#   'Chear',
#   'Lemon',
#   'Lime',
#   'Coconot',
#   'Apricot',
#   'Fig',
#   'Guava',
#   'Lychee',
#   'Dragon Fruit',
#   'Tangerine',
#   'Passion Fruit',
#   'Avocado'],
#  ['Carrot',
#   'Spinach',
#   'Potato',
#   'Tomato',
#   'Cucumber',
#   'Lettuce',
#   'Kale',
#   'Cauliflower',
#   'Bell Pepper',
#   'Onion',
#   'Garlic',
#   'Eggplant',
#   'Zucchini',
#   'Cabbage',
#   'Peas',
#   'Asparagus',
#   'Brussels Sprouts',
#   'Radish',
#   'Beetroot',
#   'Pumpkin',
#   'Green Beens',
#   'Okra',
#   'Yam'])
